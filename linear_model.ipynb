# %% [markdown]
# <a href="https://colab.research.google.com/github/vKrish14/Complete-Python-Bootcamp/blob/main/linear_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Import Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# **2. Creating random dataset**

# %%
X = np.random.rand(20).reshape(-1,1)
Y = np.random.rand(20)

print("X = ", X)
print("\nY = ", Y)
# Out:
# X =  [[0.72868792]
#  [0.90316836]
#  [0.89900079]
#  [0.239306  ]
#  [0.55955217]
#  [0.88290308]
#  [0.92736301]
#  [0.3648032 ]
#  [0.43205153]
#  [0.18494549]
#  [0.41456951]
#  [0.55375483]
#  [0.04189371]
#  [0.85683806]
#  [0.95670574]
#  [0.73158845]
#  [0.85750576]
#  [0.65726257]
#  [0.84102452]
#  [0.41243369]]
#
# Y =  [0.00405319 0.59066163 0.41557726 0.77723333 0.29426238 0.53274751
#  0.50441555 0.84292052 0.37997736 0.91965049 0.56404104 0.48123782
#  0.565287   0.90416192 0.37993087 0.15862562 0.62394973 0.96877879
#  0.05238907 0.86097175]

# %% [markdown]
# **3. Splitting data into train and test dataset**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 20 )

print("X_train",X_train)

print("\nX_test",X_test)

print("\nY_train",Y_train)

print("\nY_test",Y_test)
# Out:
# X_train [[0.65726257]
#  [0.04189371]
#  [0.41243369]
#  [0.88290308]
#  [0.43205153]
#  [0.84102452]
#  [0.72868792]
#  [0.89900079]
#  [0.3648032 ]
#  [0.92736301]
#  [0.55375483]
#  [0.18494549]
#  [0.73158845]
#  [0.239306  ]]
#
# X_test [[0.85750576]
#  [0.85683806]
#  [0.41456951]
#  [0.55955217]
#  [0.90316836]
#  [0.95670574]]
#
# Y_train [0.96877879 0.565287   0.86097175 0.53274751 0.37997736 0.05238907
#  0.00405319 0.41557726 0.84292052 0.50441555 0.48123782 0.91965049
#  0.15862562 0.77723333]
#
# Y_test [0.62394973 0.90416192 0.56404104 0.29426238 0.59066163 0.37993087]

# %% [markdown]
# **4. Creating an instance for the linear regression model**

# %%
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %% [markdown]
# **5. Creating/Train Linear Model**

# %%
# Training the model by passing the dependent and independent features of the training dataset
lr.fit(X_train, Y_train)
lr
# Out:
# LinearRegression()

# %% [markdown]
# **6. Make prediction on test dataset**

# %%
Y_pred = lr.predict( X_test)

print(Y_pred)
# Out:
# [0.36448359 0.36486734 0.61905974 0.53573143 0.33823916 0.30746873]

# %% [markdown]
# **7. Model Evaluation**

# %% [markdown]
# **7.1 Get the coefficients**

# %%
# The value of the coefficients for the independent feature through the multiple regression model
print("Value of the oefficients: \n", lr.coef_)
# Out:
# Value of the oefficients:
#  [-0.57474672]

# %% [markdown]
# **7.2 Get Mean squared error between Actual and Predicted**

# %%
# The value of the mean squared error
print(f"Mean square error: {mean_squared_error( Y_test, Y_pred)}")
# Out:
# Mean square error: 0.08141059021908192

# %% [markdown]
# **7.3 Get R Square between Actual and Predicted**

# %%
# The value of the coefficient of determination, i.e., R-square score of the model
print(f"Coefficient of determination: {r2_score( Y_test, Y_pred )}")
# Out:
# Coefficient of determination: -1.1562545352550169

# %% [markdown]
# **7.4 Scatter Plot**

# %%
# Plotting the output
plt.scatter(X_test, Y_test, color = "black", label = "original data")
plt.plot(X_test, Y_pred, color = "blue", linewidth=3, label = "regression line")
plt.xlabel("Independent Feature")
plt.ylabel("Target Values")
plt.title("Simple Linear Regression")
plt.show()
